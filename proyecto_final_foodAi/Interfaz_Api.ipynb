# %% [markdown]
# En este notebook vamos a utilizar la libreria streamlit para crear una interfaz que se conecte con nuestra API simplemente para darle un poco más de estilo a nuestras respuestas de API

# %% [markdown]
# Accedere a mi google colab para acceder luego a app.py que creare y guardare (donde estará el código de mi interfaz

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# instalo la libreria streamlit y tambien con pyngrok

# %%
# !pip install streamlit       # Instala Streamlit, la biblioteca para crear interfaces web interactivas en Python.
# !pip install streamlit pyngrok -q  # Instalo Streamlit y Pyngrok (usado para exponer la app en la web), con `-q` para suprimir salida extensa.

# %% [markdown]
# Voy a crear el codigo donde preparo la interfaz y la guardo en un archivo llamado app.py. Esta celda guarda el código de una interfaz en Streamlit para la predicción de platos basada en imágenes. Permite subir una imagen de un plato, la envía a una API para su análisis, luego muestra el nombre del plato, sus calorías, macronutrientes, ingredientes y un enlace a la receta.
# Finalmente, el código se guarda en la ruta especificada para su posterior ejecución.
#
# **Es importante que se esté ejecutando el código donde tenemos la API, porque sino esta corriendo no funcionará y además tiene que coincidir la API_URL que te arroja ngrok con la que se pone en este código y siempre que corras de nuevo la API, poner la URL ue te arroja en ese momento**

# %%
# Ruta donde se guardará el archivo
ruta_guardado = "/content/drive/MyDrive/tokio/deep_learning/proyecto_final_foodAi/app.py"

# Código de la interfaz Streamlit
codigo = """import streamlit as st
import requests
import json
from PIL import Image

# URL de la API
API_URL = "https://fe4a-104-196-143-67.ngrok-free.app"

st.set_page_config(page_title="Predicción de Platos", page_icon="🍽️", layout="wide")

st.title("🍽️ Predicción de Platos")

uploaded_file = st.file_uploader("📷 Sube una imagen del plato", type=["jpg", "png", "jpeg"])

if uploaded_file:
    image = Image.open(uploaded_file)
    st.image(image, caption="Imagen subida", use_container_width=True)

    with st.spinner("⏳ Analizando imagen..."):
        files = {"file": uploaded_file.getvalue()}
        response = requests.post(f"{API_URL}/predict", files=files)

    if response.status_code == 200:
        result = response.json()
        st.success("✅ Predicción realizada con éxito")

        st.markdown("### 🍽️ Plato:")
        st.markdown(f"<p style='font-size: 22px; font-weight: bold;'>{result['plato']}</p>", unsafe_allow_html=True)

        st.markdown("### 🔥 Calorías:")
        st.markdown(f"<p style='font-size: 22px; font-weight: bold;'>{result['calorias']} kcal</p>", unsafe_allow_html=True)

        st.markdown("### 🛢️ Grasas:")
        st.markdown(f"<p style='font-size: 22px; font-weight: bold;'>{result['grasas']} g</p>", unsafe_allow_html=True)

        st.markdown("### 🍞 Carbohidratos:")
        st.markdown(f"<p style='font-size: 22px; font-weight: bold;'>{result['carbohidratos']} g</p>", unsafe_allow_html=True)

        st.markdown("### 💪 Proteínas:")
        st.markdown(f"<p style='font-size: 22px; font-weight: bold;'>{result['proteinas']} g</p>", unsafe_allow_html=True)

        # Mostrar ingredientes correctamente alineados
        if result.get("ingredientes") and result["ingredientes"] != "No disponible":
            st.markdown("### 📜 Ingredientes:")
            ingredientes_lista = result["ingredientes"].splitlines()
            ingredientes_limpios = [ing.strip("- ").strip() for ing in ingredientes_lista if ing.strip()]
            for ing in ingredientes_limpios:
                st.markdown(f"- {ing}")

        # Mostrar enlace de la receta si está disponible
        if result.get("url_receta") and result["url_receta"] != "No disponible":
            st.markdown(f"📌 **[Ver Receta]({result['url_receta']})**", unsafe_allow_html=True)

    else:
        st.error("❌ Error en la predicción")
"""

# Guardo el código en un archivo
with open(ruta_guardado, "w", encoding="utf-8") as f:
    f.write(codigo)

print(f"✅ Archivo guardado en {ruta_guardado}")
# Out:
# ✅ Archivo guardado en /content/drive/MyDrive/tokio/deep_learning/proyecto_final_foodAi/app.py

# %%
# !wget -q -O - https://loca.lt/mytunnelpassword #necesario este codigo pra obtener la contraseña paera acceder a la interfaz
# Out:
# 35.247.11.132

# %% [markdown]
# Explicación:
#
# Popen: Lanza la aplicación de Streamlit en segundo plano.
#
# time.sleep(3): Da tiempo para que la aplicación arranque antes de exponerla.
#
# !npx localtunnel --port 8501: Usa LocalTunnel para generar una URL pública que permita acceder a la app desde cualquier lugar.

# %%
# Importo módulos y ejecuto la app en segundo plano
import time
from subprocess import Popen

Popen(["streamlit", "run", "/content/drive/MyDrive/tokio/deep_learning/proyecto_final_foodAi/app.py"])

# Espero con ello unos segundos para que inicie
time.sleep(3)

# Expongo la app con Ngrok
# !npx localtunnel --port 8501
# Out:
# ⠙⠹⠸⠼⠴⠦your url is: https://thirty-ghosts-repeat.loca.lt
# ^C
